# %%
import pandas as pd

# %%
dataset = pd.read_csv("./delaney-processed.csv")
dataset.describe()
dataset.head(50)
# Out:
#                           Compound ID  \
# 0                           Amigdalin
# 1                            Fenfuram
# 2                              citral
# 3                              Picene
# 4                           Thiophene
# 5                       benzothiazole
# 6                      2,2,4,6,6'-PCB
# 7                           Estradiol
# 8                            Dieldrin
# 9                            Rotenone
# 10                      2-pyrrolidone
# 11                 2-Chloronapthalene
# 12                         1-Pentene
# 13                          Primidone
# 14                        Tetradecane
# 15                    2-Chloropropane
# 16                    2-Methylbutanol
# 17                       Benzonitrile
# 18                           Diazinon
# 19                        2-Undecanol
# 20                     2,2',3,4,6-PCB
# 21                            Lenacil
# 22                            Phorate
# ...
